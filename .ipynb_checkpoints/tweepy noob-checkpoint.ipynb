# %%
import tweepy
import pandas as pd
import numpy as np
import json
import re
import requests

# %%
tw_archive = pd.read_csv("twitter-archive-enhanced.csv")  # Load the twitter archive data for @WeRateDogs.
im_predict = pd.read_csv("image_predictions.tsv", delimiter="\t")

# %% [markdown]
# # Clean

# %%
tw_archive_clean = tw_archive.copy()
im_predict_clean = im_predict.copy()

# %%
tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
tw_keys = pd.read_json("../API keys.json").Twitter
auth = tweepy.OAuthHandler(tw_keys.consumer_key, tw_keys.consumer_secret)
auth.set_access_token(tw_keys.access_token, tw_keys.access_token_secret)

api = tweepy.API(auth,
                wait_on_rate_limit=True,
                wait_on_rate_limit_notify=True)

# %% [raw]
# for tweet in [856330835276025856]:
#     twee = api.get_status(tweet, tweet_mode='extended')
#
# twee = json.dumps(twee._json)
# print(twee)

# %%
if "retweeted_status" in twee.keys():
    tweet = "retweet"
elif twee["in_reply_to_status_id"] != None:
    tweet = "reply"
else:
    tweet = "original"

# %%
tw_archive_clean.replace(to_replace="None", value=np.NaN, inplace=True)

# %%
tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1611 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# ...

# %%
dog_stage_df = pd.melt(tw_archive_clean, id_vars=["tweet_id"], 
                    value_vars=["doggo", "floofer", "pupper", "puppo"],
                   value_name="dog_stage").dropna().drop("variable", axis=1)
tw_archive_clean = tw_archive_clean.merge(dog_stage_df, on="tweet_id", how="left")

# %%
tw_archive_clean[tw_archive_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
t_url = "https://twitter.com/dog_rates/status/"
null_expn_urls = tw_archive_clean[pd.isnull(tw_archive_clean.expanded_urls)]["tweet_id"].tolist()
for tweet in null_expn_urls:
    response = requests.get(t_url + str(tweet))
    if response.history:
        print("Request was redirected")
        print("Final destination:")
        print(response.status_code, response.url)
    else:
        print("Request was not redirected")
        print(response.url)
# Out:
# Request was not redirected
# https://twitter.com/dog_rates/status/886267009285017600
# Request was not redirected
# https://twitter.com/dog_rates/status/881633300179243008
# Request was not redirected
# https://twitter.com/dog_rates/status/879674319642796034
# Request was not redirected
# https://twitter.com/dog_rates/status/870726314365509632
# Request was not redirected
# https://twitter.com/dog_rates/status/863427515083354112
# Request was not redirected
# https://twitter.com/dog_rates/status/857214891891077121
# Request was redirected
# Final destination:
# 200 https://twitter.com/Jenna_Marbles/status/856330158768218112
# Request was not redirected
# https://twitter.com/dog_rates/status/856288084350160898
# Request was not redirected
# https://twitter.com/dog_rates/status/855862651834028034
# Request was not redirected
# https://twitter.com/dog_rates/status/855860136149123072
# Request was not redirected
# https://twitter.com/dog_rates/status/850333567704068097
# ...

# %% [markdown]
# Going forward, we need a combined dataset of `tw_archive_clean` and `im_predict_clean`. There's also some columns in the `tw_archive_clean` dataset that arent necessary for our analysis. <br>
# While combining the datasets, I'd like to access tweets that are of dogs. All other tweets are not needed.

# %%
im_predict_clean["dog"] = (im_predict_clean[["p1_dog", "p2_dog", "p3_dog"]].any(axis=1))

# %%
im_predict_clean = im_predict_clean[im_predict_clean.dog]

# %%
im_predict_clean
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11    666071193221509120    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...
